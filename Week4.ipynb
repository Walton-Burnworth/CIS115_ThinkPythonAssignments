# %% [markdown]
# <a href="https://colab.research.google.com/github/Walton-Burnworth/CIS115_ThinkPythonAssignments/blob/main/Week4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Statement
# None

# Function Definitions
# 1. Define print_bio with three parameters: name, age, and goal.
def print_bio (name, age, goal) :
    # 2. Inside the functions, use string multiplication (*) for a border line.
    border = print("*" * 25)

    # 3. Print the bio details using the parameter names.
    print(f"Name: {name}", f"Age: {age}", f"Goal: {goal}")
    print("*" * 25)

# Program Logic
# 1. Call print_bio using my own info.
print_bio("Walton", 17, "Become fluent in the language of Python.")
print()
# 2. Call print_bio using [ Chris Pratt ]
print_bio("Chris Pratt", 45, "Continue acting and being a family man.")
print()
# 3. Call print_bio using [ Shrek ]
print_bio("Shrek", "34", "Live happily ever after.")
print()
# Out:
# *************************
# Name: Walton Age: 17 Goal: Become fluent in the language of Python.
# *************************
#
# *************************
# Name: Chris Pratt Age: 45 Goal: Continue acting and being a family man.
# *************************
#
# *************************
# Name: Shrek Age: 34 Goal: Live happily ever after.
# *************************
