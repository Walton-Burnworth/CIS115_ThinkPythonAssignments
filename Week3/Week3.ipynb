# %% [markdown]
# <a href="https://colab.research.google.com/github/Walton-Burnworth/CIS115_ThinkPythonAssignments/blob/main/Week3/Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Statements

# Function Definitions

# Program Logic
# Assign values to variables: name, goal, birth_year, current_year
name = "Walton Burnworth"
goal = " to have a successful career in cyber security."
birth_year = "2008"
current_year = "2026"
# Calculate age
age = int(current_year) - int(birth_year)
# Print top border
print( "=" * 25 )
# Print bio sentence
print("My name is " + name + " and I am " + str(age) + " years old." + " My goal is" + goal)
# Print bottom border
print( "=" * 25 )
# Out:
# ...
# My name is Walton Burnworth and I am 18 years old. My goal is to have a successful career in cyber security.
# ...
