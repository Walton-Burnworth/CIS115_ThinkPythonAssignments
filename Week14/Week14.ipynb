# %% [markdown]
# <a href="https://colab.research.google.com/github/Walton-Burnworth/CIS115_ThinkPythonAssignments/blob/main/Week14/Week14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Name: Library.py
# IMPORT STATEMENTS
# None


# Class DEFINITIONS
# Define a class named Book
class Book:
  # Define __init__ method to accept title and author
  def __init__(self, title, author):
        self.title = title
        self.author = author
  # Include is_available attribute (default to True)
        self.is_available = True

  # Define __str__ method

  # Return string: "Title by Author - Status"

  # Define checkout() method
  # Set is_available to False

  # Define return_book() method
  # Set is_available to True


# PROGRAM LOGIC
# Step 1: Create at least two separate instances (objects) of Book
book1 = Book("Think Python", "Allen Downey")
book2 = Book("The Hobbit", "J.R.R. Tolkien")
# Step 2: Print the initial status of both books
# Step 3: Call the checkout) method on one of the books
# Step 4: Print both books again to show the updated status

# Midpoint:
print(f"Testing Library Setup...")
print(f"Book 1 Title: {book1.title}")
# Out:
# Testing Library Setup...
# Book 1 Title: Think Python
