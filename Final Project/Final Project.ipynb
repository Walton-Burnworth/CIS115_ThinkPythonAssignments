# %% [markdown]
# <a href="https://colab.research.google.com/github/Walton-Burnworth/CIS115_ThinkPythonAssignments/blob/main/Final%20Project/Final%20Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: expense_tracker.py

# Import Statements
# None


# Function Defintion
# Function 1: calculate_total(expense_list, filter_type, filter_value)
def calculate_total(expense_list, filter_type=None, filter_value=None):
  pass
  # Goal: Initialize total at 0.0. Loop through the list.
  # If filter matches (or no filter), add expense['amount'] to total.
  # Return the final sum.


# Program Logic

# 1. Initialize an empty list 'master_expenses' to hold dictionaries.
master_expenses = []
# 2. Main Loop (while True):
#    a. Display menu: 1. Add Expense, 2. Get Totals, 3. Exit.
#    b. Get user selection.
while True:
    print("\n--- Expense Tracker ---")
    print("1. Add New Expense")
    print("2. Get Totals")
    print("3. Exit")

    selection = input("Selection: ")

#    c. If selection is "1":
#       - Prompt for Category, Vendor, Amount, and Date.
#       - Use try/except to convert Amount to float (handle errors).
#       - Create dictionary and .append() to master_expenses.
    if selection == "1":
        category = input("Enter Category: ")
        vendor = input("Enter Vendor: ")
        date = input("Enter Date (YYYY-MM-DD): ") # Added missing date input

        try:
            amount = float(input("Enter Amount: "))
        except ValueError:
            print("Invalid amount. Please enter a number.")
            continue

        expense_record = {
            "category": category,
            "vendor": vendor,
            "amount": amount,
            "date": date
        }

        master_expenses.append(expense_record)

        print(f"Current List: {master_expenses}")

#    d. If selection is "2":
#       - Prompt for filter choice: (A)ll, (C)ategory, or (V)endor.
#       - If C or V, prompt for the specific name (e.g., "Groceries").
#       - Call calculate_total() with the correct arguments.
#       - Print result formatted to 2 decimal places (e.g., $10.00).
    elif selection == "2":
        # Placeholder for Commit 3
        print("Totals feature coming in the next commit!")

#    e. If selection is "3":
#       - Print goodbye message and 'break' the loop.
    elif selection == "3":
        print("Goodbye!")
        break

# 3. Standard boilerplate to call main()
# Out:
# --- Expense Tracker ---
# 1. Add New Expense
# 2. Get Totals
# 3. Exit
