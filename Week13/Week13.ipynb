# %% [markdown]
# <a href="https://colab.research.google.com/github/Walton-Burnworth/CIS115_ThinkPythonAssignments/blob/main/Week13/Week13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# None


# FUNCTION DEFINITIONS
# Define write_entry(filename, entry)
def write_entry(filename, entry):
  # Open filename in append made ('a')
  with open(filename, 'a') as file:
    # Write entry plus a newline character
    file.write(entry + "\n")
  print("Entry Saved.")
# Close the file

# Define read_journal(filename)
def read_journal(filename):
  # Use try/except to handle FileNotFoundError
  try:
    # Open filename in read mode ('r')
    with open(filename, 'r') as file:
      # Read and print the contents
      content = file.read()
      print("Journal Entries:\n" + content)
  except FileNotFoundError:
    print(f"Error: The journal file '{filename}' was not found.")


# PROGRAM LOGIC
# Step 1: Set a variable for the journal filename
journal_name = "journal.text"
# Step 2: Start a while loop that runs until the user types "quit."
while True:
  # Step 3: Ask user for (W)rite, (R)ead, or (Q)uit
  choice = input("(W)rite, (R)ead, or (Q)uit: ").upper()
  # Step 4: If 'W', ask for entry and call write_entry
  if choice == 'W':
    user_entry = input("Enter your journal entry: ")
    write_entry(journal_name, user_entry)
  # Step 5: If 'R', call read_journal
  elif choice == 'R':
    read_journal(journal_name)
  # Step 6: If 'Q', break the loop
  elif choice == 'Q':
    print("Goodbye!")
    break
  # Handle invalid inputs
  else:
    print("Invalid choice. Please type W, R, or Q.")
# Out:
# Invalid choice. Please type W, R, or Q.
