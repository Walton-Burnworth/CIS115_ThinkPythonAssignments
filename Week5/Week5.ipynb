# %% [markdown]
# <a href="https://colab.research.google.com/github/Walton-Burnworth/CIS115_ThinkPythonAssignments/blob/main/Week5/Week5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Statements
# None

# Function Definitioins
# 1. Define calculate_ticket(age, hour)
# 2. Logic:  If age <= 12 or age >= 65, price = 8.
  # Otherwise, price = 12.
# 3. Logic: If hour < 17, subtract 2 from the price.
# 4. Print the final price.

# Program Logic
# 1. input() for age (int)
# 2. input() for movie hour (int)
# 3. call calculate_ticket()
